# %%
import gym
env = gym.make("CartPole-v1")

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
for action in range(env.action_space.n):
  print(action)
# Out:
# 0
# 1

# %%
# the poles's starting state:
env.reset()
# Out:
# (array([ 0.02464805,  0.01900045, -0.03181395,  0.02836171], dtype=float32),
#  {})

# %%
env.step(action=0)
# return: obs/next state, reward, terminated, truncated, info
# Out:
# (array([ 0.02502805, -0.17565116, -0.03124672,  0.31083965], dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %%
# train stage PPO
# https://stable-baselines3.readthedocs.io/en/master/modules/ppo.html
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import gym
env = gym.make("CartPole-v1")
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1) # hide log
model.learn(total_timesteps=100000)
model.save('cartpole_ppo_model')
env.close()
# Out:
# C:\Users\Window10\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 1535 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 933        |
# |    iterations           | 2          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.00870229 |
# |    clip_fraction        | 0.0987     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.686     |
# |    explained_variance   | -0.00387   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.99       |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0169    |
# |    value_loss           | 59.8       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 814         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009569382 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.0653      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.1        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 39.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 742         |
# |    iterations           | 4           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009985359 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.629      |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 46.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 640         |
# |    iterations           | 5           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011146171 |
# |    clip_fraction        | 0.0701      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0153     |
# |    value_loss           | 57.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 6            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0046083326 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.599       |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.3         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00835     |
# |    value_loss           | 59           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 618          |
# |    iterations           | 7            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0061597317 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.765        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.15         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 39.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 8           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005565162 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00798    |
# |    value_loss           | 46.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 9           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006504127 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.806       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 39          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 626         |
# |    iterations           | 10          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.008285056 |
# |    clip_fraction        | 0.0952      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.573      |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.13        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0125     |
# |    value_loss           | 21.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 635         |
# |    iterations           | 11          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.009433432 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.57       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.31        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 24.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 642          |
# |    iterations           | 12           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0047016786 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.856        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00724     |
# |    value_loss           | 9.56         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 648         |
# |    iterations           | 13          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007916264 |
# |    clip_fraction        | 0.0474      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.564      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.71        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00514    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 652          |
# |    iterations           | 14           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0072103846 |
# |    clip_fraction        | 0.0686       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.548       |
# |    explained_variance   | 0.759        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.8          |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00787     |
# |    value_loss           | 5.59         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 15          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009075202 |
# |    clip_fraction        | 0.0801      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.322       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.216       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 2           |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 16          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006721403 |
# |    clip_fraction        | 0.053       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.109       |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00519    |
# |    value_loss           | 1.05        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 654          |
# |    iterations           | 17           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0044729616 |
# |    clip_fraction        | 0.0567       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.525       |
# |    explained_variance   | 0.0164       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0165       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00266     |
# |    value_loss           | 0.663        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 18          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.004629764 |
# |    clip_fraction        | 0.0317      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.527      |
# |    explained_variance   | 0.00726     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0116      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 0.422       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 19          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.004408064 |
# |    clip_fraction        | 0.0348      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.0211      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0287      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 0.268       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 651         |
# |    iterations           | 20          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.003026207 |
# |    clip_fraction        | 0.0206      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | -0.0147     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00609     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000632   |
# |    value_loss           | 0.173       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 21          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.002568421 |
# |    clip_fraction        | 0.0135      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.541      |
# |    explained_variance   | 0.00532     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00579     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 7.1e-05     |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 630          |
# |    iterations           | 22           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0067806365 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0.0235       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.011        |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 0.0685       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 624         |
# |    iterations           | 23          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.002090278 |
# |    clip_fraction        | 0.00957     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.509      |
# |    explained_variance   | -0.0118     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00148     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.000128    |
# |    value_loss           | 0.0407      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 24          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005663666 |
# |    clip_fraction        | 0.0552      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.0421      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00224    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00284    |
# |    value_loss           | 0.0261      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 631         |
# |    iterations           | 25          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.002220029 |
# |    clip_fraction        | 0.0326      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.0226      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0123     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 0.0172      |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 634      |
# |    iterations           | 26       |
# |    time_elapsed         | 83       |
# |    total_timesteps      | 53248    |
# | train/                  |          |
# |    approx_kl            | 0.005674 |
# |    clip_fraction        | 0.0834   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.513   |
# |    explained_variance   | 0.016    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.00564 |
# |    n_updates            | 250      |
# |    policy_gradient_loss | -0.00509 |
# |    value_loss           | 0.0112   |
# --------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 27           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0035329808 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.536       |
# |    explained_variance   | 0.00728      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0108      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000648    |
# |    value_loss           | 0.0073       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 28           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0008789613 |
# |    clip_fraction        | 0.00786      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.513       |
# |    explained_variance   | -0.0111      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00478     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.000399     |
# |    value_loss           | 0.00488      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 29           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0064962967 |
# |    clip_fraction        | 0.0613       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.522       |
# |    explained_variance   | -0.0178      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0193      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00256     |
# |    value_loss           | 0.00331      |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 637        |
# |    iterations           | 30         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00523272 |
# |    clip_fraction        | 0.049      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.508     |
# |    explained_variance   | -0.0256    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00665    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00318   |
# |    value_loss           | 0.00219    |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 640          |
# |    iterations           | 31           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0038008322 |
# |    clip_fraction        | 0.0434       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | -0.0334      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00446      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 0.0015       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 643         |
# |    iterations           | 32          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008898959 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.489      |
# |    explained_variance   | 0.0222      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0216     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00204    |
# |    value_loss           | 0.001       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 33           |
# |    time_elapsed         | 104          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0057275565 |
# |    clip_fraction        | 0.0392       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.47        |
# |    explained_variance   | 0.00389      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.000851    |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00176     |
# |    value_loss           | 0.000723     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 650         |
# |    iterations           | 34          |
# |    time_elapsed         | 106         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005176231 |
# |    clip_fraction        | 0.0776      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.477      |
# |    explained_variance   | -0.0506     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00272     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00349    |
# |    value_loss           | 0.000512    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 653         |
# |    iterations           | 35          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.007026611 |
# |    clip_fraction        | 0.0598      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.47       |
# |    explained_variance   | -0.00731    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00615     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00225    |
# |    value_loss           | 0.000326    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 655         |
# |    iterations           | 36          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004709637 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.471      |
# |    explained_variance   | -0.15       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00476     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00224    |
# |    value_loss           | 0.000249    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 652         |
# |    iterations           | 37          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.002853462 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.462      |
# |    explained_variance   | -0.021      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00706     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 0.000182    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 647          |
# |    iterations           | 38           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0056131156 |
# |    clip_fraction        | 0.0656       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | -0.0681      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0148      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00446     |
# |    value_loss           | 0.00013      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 647         |
# |    iterations           | 39          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.009011859 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.451      |
# |    explained_variance   | -0.0998     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0103      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 9.86e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 644        |
# |    iterations           | 40         |
# |    time_elapsed         | 127        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00422258 |
# |    clip_fraction        | 0.065      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.432     |
# |    explained_variance   | -0.0667    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0114    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00237   |
# |    value_loss           | 6.19e-05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 41           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0030242475 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | -0.0183      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00558     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 4.48e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 645          |
# |    iterations           | 42           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0045097684 |
# |    clip_fraction        | 0.0749       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.41        |
# |    explained_variance   | -0.0428      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0189       |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 4.19e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 645         |
# |    iterations           | 43          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.003406177 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.416      |
# |    explained_variance   | -0.137      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00119     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00042    |
# |    value_loss           | 2.66e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 44          |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004896066 |
# |    clip_fraction        | 0.0636      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.403      |
# |    explained_variance   | -0.318      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00266    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00283    |
# |    value_loss           | 1.9e-05     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 644          |
# |    iterations           | 45           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0056278706 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.391       |
# |    explained_variance   | -0.704       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00861     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 1.87e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 638          |
# |    iterations           | 46           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0035047305 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.401       |
# |    explained_variance   | -0.589       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00782     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 1.36e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 635          |
# |    iterations           | 47           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0029370284 |
# |    clip_fraction        | 0.0263       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | -0.596       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.39e-05     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 1.27e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 48           |
# |    time_elapsed         | 154          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0019218575 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.371       |
# |    explained_variance   | -0.428       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.002       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 7.61e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 638         |
# |    iterations           | 49          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.004916946 |
# |    clip_fraction        | 0.0495      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | -0.461      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00428     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 7.04e-06    |
# -----------------------------------------

# %%
import gym
from PIL import Image
from stable_baselines3 import PPO
env = gym.make("CartPole-v1", render_mode='rgb_array')
obs, info = env.reset()
screen = env.render() # render image
images= [Image.fromarray(screen)]
i = 1
truncated = False
while (not truncated) and i <= 1000:
  action = env.action_space.sample()
  model = PPO.load("cartpole_ppo_model")
  action, states = model.predict(obs, deterministic =True)
  obs, reward, terminated, truncated, info = env.step(action)
  if (i%100 == 0): print("step", i, "action", action, obs, reward, terminated, info)
  i += 1
  screen=env.render()
  images.append(Image.fromarray(screen))
  env.close()

image_file = '63130500113-cartpole-v1-PPO.gif'
# loop=0: loop forever, duration=1: play each frame for ims
images[0].save(image_file, save_all =True, append_images=images[1:], loop=1, duration=1)
# Out:
# step 100 action 1 [ 0.30153978  0.01557292 -0.01578305 -0.0860551 ] 1.0 False {}
# step 200 action 0 [ 0.17144533  0.00961364 -0.00075421  0.04541368] 1.0 False {}
# step 300 action 0 [ 0.21665552  0.01204553 -0.00170038 -0.00823242] 1.0 False {}
# step 400 action 1 [ 0.21790631  0.0126099   0.00428678 -0.02068246] 1.0 False {}
# step 500 action 1 [ 0.21953093  0.01256703  0.00202602 -0.01973692] 1.0 False {}

# %%
# train stage DQN
import gymnasium as gym
from stable_baselines3 import DQN
env = gym.make("CartPole-v1", render_mode="human")
model = DQN("MlpPolicy", env, verbose=1) # hide log
model.learn(total_timesteps = 10000, log_interval=4)
model.save("dqn_cartpole")
env.close()

# %%
import gymnasium as gym
from PIL import Image
from stable_baselines3 import DQN
env = gym.make("CartPole-v1", render_mode='rgb_array')
env.reset()
screen = env.render() # render image
images= [Image.fromarray(screen)]
i = 1
truncated = False
while (not truncated) and i <= 100:
  action = env.action_space.sample()
  model = DQN.load("dqn_cartpole")
  # obs, info = env.reset()
  action, states = model.predict(obs, deterministic =True)
  obs, reward, terminated, truncated, info = env.step(action)
  if (i%5 == 0): print ("step", i, "action", action, obs, reward, terminated, info)
  screen=env.render()
  images.append(Image.fromarray(screen))
  # if terminated or truncated:
  #   obs, info = env.reset()
  i += 1
  env.close()

image_file = '63130500113-cartpole-v1-DQN.gif'
# loop=0: loop forever, duration=1: play each frame for ims
images[0].save(image_file, save_all =True, append_images=images[1:], loop=1, duration=1)
# Out:
# step 5 action 1 [ 0.03579208  0.9882051  -0.0489381  -1.4514667 ] 1.0 False {}
# step 10 action 1 [ 0.17378734  1.9678771  -0.25737777 -3.08326   ] 1.0 True {}
# step 15 action 1 [ 0.4093853  2.927927  -0.6394004 -4.9691753] 0.0 True {}
# step 20 action 1 [ 0.71511364  3.4125738  -1.1899567  -6.492723  ] 0.0 True {}
# step 25 action 1 [ 1.0852885  4.101621  -1.9065473 -8.048179 ] 0.0 True {}
# step 30 action 1 [ 1.5205128  4.7577624 -2.7444549 -8.570825 ] 0.0 True {}
# step 35 action 1 [ 2.0313601  5.7007384 -3.563955  -7.2815375] 0.0 True {}
# step 40 action 1 [ 2.645497   6.7979584 -4.205675  -5.113517 ] 0.0 True {}
# step 45 action 1 [ 3.3667715  7.8147163 -4.6385956 -3.2502618] 0.0 True {}
# step 50 action 1 [ 4.1862383  8.754143  -4.9042115 -1.8463231] 0.0 True {}
# step 55 action 1 [ 5.0980325  9.65999   -5.043811  -0.7697154] 0.0 True {}
# step 60 action 1 [ 6.099889   10.555672   -5.0836344   0.14209874] 0.0 True {}
# step 65 action 1 [ 7.1912613 11.451677  -5.033786   1.0470749] 0.0 True {}
# step 70 action 1 [ 8.372533  12.35767   -4.8888135  2.0980701] 0.0 True {}
# step 75 action 1 [ 9.645369  13.293441  -4.6280704  3.4452841] 0.0 True {}
# step 80 action 1 [11.014124  14.296864  -4.2163625  5.218628 ] 0.0 True {}
# step 85 action 1 [12.487053  15.391771  -3.6096876  7.3808465] 0.0 True {}
# step 90 action 0 [14.022494  14.861417  -2.8609781  6.8054786] 0.0 True {}
# step 95 action 0 [15.466048 13.793911 -2.261808  4.710713] 0.0 True {}
# step 100 action 1 [16.848484  14.245665  -1.8398396  3.6877544] 0.0 True {}

# %%
from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
import gym
env = gym.make("CartPole-v1", render_mode="human")
models = {"dqn": DQN.load('dqn_cartpole'), "ppo": PPO.load('cartpole_ppo_model') }
for k, v in models.items():
    mean_rw, sd_rw = evaluate_policy(models[k], env, n_eval_episodes = 10, render=True)
    print(k,' reward: Mean', mean_rw, 'SD', sd_rw )
# Out:
# C:\Users\Window10\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# C:\Users\Window10\AppData\Local\Programs\Python\Python310\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# dqn  reward: Mean 9.3 SD 0.6403124237432849
# ppo  reward: Mean 500.0 SD 0.0
